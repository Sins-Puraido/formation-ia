# %% [markdown]
# ### Création du jeu ###
#
# dans un premier temps on créer une class TicTacToe qui represente l'environement du jeu

# %%
import random
import numpy as np
from jupyter_server.terminal import initialize


class TicTacToeEnv:
    def __init__(self):
        self.board = [0] * 9  # 9 positions sur le plateau
        self.current_winner = None

    #reset les case du plateau
    def reset(self):
        self.board = [0] * 9
        self.current_winner = None
        return tuple(self.board)

    #indique les case encore idsponible pour jouer son tour
    def available_moves(self):
        return [i for i, x in enumerate(self.board) if x == 0]

    #pose un pion sur le plateau, renvois false si la case est deja prise et renvois true si le coup fait ganger le joueur
    def make_move(self, position, player):
        if self.board[position] == 0:
            self.board[position] = player
            if self.check_winner(position, player):
                self.current_winner = player
            return True
        return False

    #liste des combinaison gagnants
    def check_winner(self, square, player):
        # Conditions de victoire
        win_conditions = [
            [0, 1, 2], [3, 4, 5], [6, 7, 8],  # lignes
            [0, 3, 6], [1, 4, 7], [2, 5, 8],  # colonnes
            [0, 4, 8], [2, 4, 6]  # diagonales
        ]
        for condition in win_conditions:
            if square in condition and all(self.board[i] == player for i in condition):
                return True
        return False

    #indique si la partie est une egalité
    def is_draw(self):
        return 0 not in self.board and self.current_winner is None
    
    #renvois l'etiat actuel du tableau, used dasn le stockage de la Q-table
    def get_state(self):
        return tuple(self.board)


    #affichage du plateau
    def render(self):
        # Affichage du plateau
        for row in [self.board[i:i + 3] for i in range(0, 9, 3)]:
            print(" | ".join([str(x) if x != 0 else " " for x in row]))
            print("-" * 5)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_68016\3454935457.py:3: DeprecationWarning: Terminals support has moved to `jupyter_server_terminals`
#   from jupyter_server.terminal import initialize

# %% [markdown]
# ### Classe de training Ai vs Random ###
#
# Dans un premier temps on entraine chaque ia contre un joueur qui joue aléatoirement pour qu'elle recupére un niveau minimum au jeu
#
# cette action nous permet d'etre plus efficace sur le training Ai contre Ai

# %%
def trainAiVsRandom(ai_agent, env, episodes, ai_starts):
    
    #on définie un joueur qui va jouer aléatoirement a chaque tour
    def random_player_move(available_moves):
        return random.choice(available_moves)

    win, loss, draw = 0, 0, 0  # Compteurs pour les statistiques de jeu

    for episode in range(1, episodes + 1):
        state = env.reset()  # Réinitialise l'environnement pour chaque partie
        done = False
        turn = 1 if ai_starts else -1  # Si ai_starts est True, l'IA commence ; sinon, le joueur aléatoire commence

        while not done:
            if turn == 1:  # Tour de l'agent IA
                available_moves = env.available_moves()
                action = ai_agent.choose_action(state, available_moves)
                env.make_move(action, ai_agent.player)
                next_state = env.get_state()

                # Vérifie le résultat après le coup de l'IA
                if env.current_winner == ai_agent.player:
                    ai_agent.update_q_table(state, action, reward=1, next_state=next_state, done=True)
                    win += 1
                    done = True
                elif env.is_draw():
                    ai_agent.update_q_table(state, action, reward=0.5, next_state=next_state, done=True)
                    draw += 1
                    done = True
                else:
                    ai_agent.update_q_table(state, action, reward=0, next_state=next_state, done=False)

                state = next_state
            else:  # Tour du joueur aléatoire
                available_moves = env.available_moves()
                action = random_player_move(available_moves)
                env.make_move(action, -ai_agent.player)
                next_state = env.get_state()

                # Vérifie le résultat après le coup du joueur aléatoire
                if env.current_winner == -ai_agent.player:
                    ai_agent.update_q_table(state, action, reward=-1, next_state=next_state, done=True)
                    loss += 1
                    done = True
                elif env.is_draw():
                    ai_agent.update_q_table(state, action, reward=0.5, next_state=next_state, done=True)
                    draw += 1
                    done = True
                else:
                    # Pas de mise à jour pour le joueur aléatoire
                    state = next_state

            turn *= -1  # Change le tour

        # Décroît l'exploration de l'IA après chaque partie
        ai_agent.decay_epsilon()

        # Affiche les statistiques tous les 1000 épisodes pour voir l'avancé de l'IA
        if episode % 1000 == 0:
            print(f"Épisode {episode} - Victoires de l'IA: {win}, Défaites de l'IA: {loss}, Égalités: {draw}")
            win, loss, draw = 0, 0, 0  # Réinitialise les compteurs pour la prochaine série

    print("Entraînement terminé")

# %%
def trainAiVsMinMaxer(agent, minimax_agent, env, episodes=10000, print_every=1000, player=True):
    win_agent, win_minimax, draw = 0, 0, 0  # Compteurs pour les statistiques

    for episode in range(1, episodes + 1):
        board = env.reset()  # Réinitialise l'environnement pour chaque partie
        done = False
        turn = 1 if player else -1  # Si l'agent Q-learning commence (joueur 1), sinon l'agent Minimax

        while not done:
            if turn == 1:  # Tour de l'agent Q-learning
                available_actions = env.available_moves()
                action = agent.choose_action(board, available_actions)
                if env.make_move(action, 1):  # L'agent Q-learning (joueur 1) fait son mouvement
                    if env.current_winner == 1:  # Vérifier si l'agent Q-learning a gagné
                        agent.update_q_table(board, action, reward=1, next_state=env.get_state(), done=True)
                        win_agent += 1
                        done = True
                    elif env.is_draw():  # Vérifier si c'est une égalité
                        agent.update_q_table(board, action, reward=0.5, next_state=env.get_state(), done=True)
                        draw += 1
                        done = True
                    else:
                        agent.update_q_table(board, action, reward=0, next_state=env.get_state(), done=False)
                board = env.get_state()

            else:  # Tour de l'agent Minimax
                available_actions = env.available_moves()
                action = minimax_agent.choose_action(board, env)  # Choisir le coup avec Minimax
                if env.make_move(action, -1):  # L'agent Minimax (joueur -1) fait son mouvement
                    if env.current_winner == -1:  # Vérifier si l'agent Minimax a gagné
                        agent.update_q_table(board, action, reward=-2, next_state=env.get_state(), done=True)
                        win_minimax += 1
                        done = True
                    elif env.is_draw():  # Vérifier si c'est une égalité
                        agent.update_q_table(board, action, reward=0.5, next_state=env.get_state(), done=True)
                        draw += 1
                        done = True
                board = env.get_state()

            # Vérification de l'égalité
            if env.is_draw() and not done:
                agent.update_q_table(board, action, reward=0.5, next_state=env.get_state(), done=True)
                draw += 1
                done = True

            turn *= -1  # Change le tour

        # Décroît l'exploration de l'agent Q-learning après chaque partie
        agent.decay_epsilon()

        # Affiche les statistiques tous les `print_every` épisodes
        if episode % print_every == 0:
            print(f"Épisode {episode} - Victoires Agent: {win_agent}, Victoires Minimax: {win_minimax}, Égalités: {draw}")
            win_agent, win_minimax, draw = 0, 0, 0  # Réinitialise les compteurs pour la prochaine série

    # Affiche les statistiques finales après l'entraînement complet
    print("Entraînement terminé")

# %%
import random

def trainAiVsPreProgrammedAgent(q_agent, preprogrammed_agent, env, episodes=10000, print_every=1000, q_agent_first=True):
    win_q_agent, win_preprogrammed, draw = 0, 0, 0  # Counters for stats

    for episode in range(1, episodes + 1):
        board = env.reset()  # Reset the environment at the start of each episode
        done = False
        turn = 1 if q_agent_first else -1  # Q-learning agent goes first if q_agent_first is True

        while not done:
            if turn == 1:  # Q-learning agent's turn
                available_moves = env.available_moves()
                action = q_agent.choose_action(board, available_moves)
                if env.make_move(action, q_agent.player):
                    next_state = env.get_state()
                    if env.current_winner == q_agent.player:  # Q-learning agent wins
                        q_agent.update_q_table(board, action, reward=1, next_state=next_state, done=True)
                        win_q_agent += 1
                        done = True
                    elif env.is_draw():  # Draw game
                        q_agent.update_q_table(board, action, reward=0.5, next_state=next_state, done=True)
                        draw += 1
                        done = True
                    else:
                        q_agent.update_q_table(board, action, reward=0, next_state=next_state, done=False)
                board = next_state

            else:  # PreProgrammedAgent's turn
                action = preprogrammed_agent.choose_action(board, env)
                if env.make_move(action, preprogrammed_agent.player):
                    if env.current_winner == preprogrammed_agent.player:  # PreProgrammedAgent wins
                        q_agent.update_q_table(board, action, reward=-1, next_state=env.get_state(), done=True)
                        win_preprogrammed += 1
                        done = True
                    elif env.is_draw():  # Draw game
                        q_agent.update_q_table(board, action, reward=0.5, next_state=env.get_state(), done=True)
                        draw += 1
                        done = True
                board = env.get_state()

            turn *= -1  # Switch turns

        # Decay exploration rate for the Q-learning agent after each episode
        q_agent.decay_epsilon()

        # Print stats every `print_every` episodes
        if episode % print_every == 0:
            print(f"Episode {episode} - Q-learning Wins: {win_q_agent}, PreProgrammed Wins: {win_preprogrammed}, Draws: {draw}")
            win_q_agent, win_preprogrammed, draw = 0, 0, 0  # Reset counters for the next print interval

    print("Training Complete")

# %%
import random

def trainAivsAi(agent1, agent2, env, episodes=10000, print_every=1000):
  
    win_agent1, win_agent2, draw = 0, 0, 0  # Compteurs pour les statistiques

    for episode in range(1, episodes + 1):
        state = env.reset()  # Réinitialise l'environnement pour chaque partie
        done = False
        turn = 1  # 1 pour agent1, -1 pour agent2

        while not done:
            if turn == 1:  # Tour de l'agent1
                available_moves = env.available_moves()
                action = agent1.choose_action(state, available_moves)
                env.make_move(action, agent1.player)
                next_state = env.get_state()

                # Vérifie le résultat après le coup de l'agent1
                if env.current_winner == agent1.player:
                    agent1.update_q_table(state, action, reward=1, next_state=next_state, done=True)
                    agent2.update_q_table(state, action, reward=-1, next_state=next_state, done=True)
                    win_agent1 += 1
                    done = True
                elif env.is_draw():
                    agent1.update_q_table(state, action, reward=1, next_state=next_state, done=True)
                    agent2.update_q_table(state, action, reward=1.5, next_state=next_state, done=True)
                    draw += 1
                    done = True
                else:
                    agent1.update_q_table(state, action, reward=0, next_state=next_state, done=False)
                state = next_state
            else:  # Tour de l'agent2
                available_moves = env.available_moves()
                action = agent2.choose_action(state, available_moves)
                env.make_move(action, agent2.player)
                next_state = env.get_state()

                # Vérifie le résultat après le coup de l'agent2
                if env.current_winner == agent2.player:
                    agent1.update_q_table(state, action, reward=-2, next_state=next_state, done=True)
                    agent2.update_q_table(state, action, reward=2, next_state=next_state, done=True)
                    win_agent2 += 1
                    done = True
                elif env.is_draw():
                    agent1.update_q_table(state, action, reward=1, next_state=next_state, done=True)
                    agent2.update_q_table(state, action, reward=1.5, next_state=next_state, done=True)
                    draw += 1
                    done = True
                else:
                    agent2.update_q_table(state, action, reward=0, next_state=next_state, done=False)
                state = next_state

            turn *= -1  # Change le tour

        # Décroît l'exploration de chaque IA après chaque partie
        agent1.decay_epsilon()
        agent2.decay_epsilon()

        # Affiche les statistiques tous les `print_every` épisodes
        if episode % print_every == 0:
            print(f"Épisode {episode} - Victoires Agent1: {win_agent1}, Victoires Agent2: {win_agent2}, Égalités: {draw}")
            win_agent1, win_agent2, draw = 0, 0, 0  # Réinitialise les compteurs pour la prochaine série

    # Affiche les statistiques finales après l'entraînement complet
    print("Entraînement terminé")

# %%
class MinimaxAgent:
    def __init__(self, player):
        self.player = player
        self.transposition_table = {}  # Initialize the transposition table

    def choose_action(self, board, env):
        """
        Choisir le meilleur coup en utilisant l'algorithme Minimax avec élagage alpha-bêta.
        """
        best_move = None
        best_score = -float('inf') if self.player == 1 else float('inf')
        alpha = -float('inf')
        beta = float('inf')

        for move in env.available_moves():
            new_board = list(board) 
            new_board[move] = self.player
            score = self.minimax(new_board, env, -self.player, alpha, beta)  # Switch player for minimax

            if (self.player == 1 and score > best_score) or (self.player == -1 and score < best_score):
                best_score = score
                best_move = move

            # Update alpha or beta based on the current player
            if self.player == 1:
                alpha = max(alpha, best_score)
            else:
                beta = min(beta, best_score)

        return best_move
    
    def minimax(self, board, env, player, alpha, beta):
        """
        Implémentation de l'algorithme Minimax avec élagage alpha-bêta et table de transposition.
        """
        board_hash = str(board)  # Create a hashable representation of the board

        # Check if the board state is already in the transposition table
        if board_hash in self.transposition_table:
            entry = self.transposition_table[board_hash]
            if entry[0] >= beta:  # If the stored score is greater than or equal to beta
                return entry[0]  # Return the stored score (beta cutoff)
            if entry[1] <= alpha:  # If the stored score is less than or equal to alpha
                return entry[1]  # Return the stored score (alpha cutoff)
            alpha = max(alpha, entry[0])  # Update alpha if necessary
            beta = min(beta, entry[1])  # Update beta if necessary

        if self.check_winner(board, 1):  
            return 1
        if self.check_winner(board, -1):  
            return -1
        if env.is_draw():  
            return 0

        best_score = -float('inf') if player == 1 else float('inf')
        for move in env.available_moves():
            env.make_move(move, player)
            score = self.minimax(env.board, env, -player, alpha, beta)
            env.board[move] = 0

            if player == 1:
                best_score = max(best_score, score)
                alpha = max(alpha, best_score)
                if alpha >= beta:
                    break  # Beta cutoff
            else:
                best_score = min(best_score, score)
                beta = min(beta, best_score)
                if beta <= alpha:
                    break  # Alpha cutoff
                    
        # Store the result in the transposition table
        if best_score <= alpha:
            self.transposition_table[board_hash] = (best_score, best_score)  # Store as (score, score) for simplicity
        elif best_score >= beta:
            self.transposition_table[board_hash] = (best_score, best_score)
        else:
            self.transposition_table[board_hash] = (alpha, beta)  # Store the updated alpha and beta values

        return best_score

    

    def check_winner(self, board, player):  
        win_conditions = [
            [0, 1, 2], [3, 4, 5], [6, 7, 8],  # lignes
            [0, 3, 6], [1, 4, 7], [2, 5, 8],  # colonnes
            [0, 4, 8], [2, 4, 6]  # diagonales
        ]
        for condition in win_conditions:
            if all(board[i] == player for i in condition):
                return True
        return False

# %%
import random

class PreProgrammedAgent:
    def __init__(self, player):
        self.player = player  # 1 for X, -1 for O
        self.opponent = -player  # Opposite player

    def choose_action(self, board, env):
        available_moves = env.available_moves()
        
        # Check if there's a winning move for the agent
        for move in available_moves:
            new_board = list(board)
            new_board[move] = self.player
            if env.check_winner(move, self.player):
                return move  # Play the winning move

        # Check if the opponent has a winning move to block
        for move in available_moves:
            new_board = list(board)
            new_board[move] = self.opponent
            if env.check_winner(move, self.opponent):
                return move  # Block the opponent

        # Look for a move that could lead to a win in the future
        for move in available_moves:
            new_board = list(board)
            new_board[move] = self.player
            if any(env.check_winner(future_move, self.player) for future_move in env.available_moves()):
                return move

        # If no strategic moves, play a random move
        return random.choice(available_moves)

# %%
class QLearningAgent:
    def __init__(self, player, alpha=0.1, gamma=0.9, epsilon=1.0, epsilon_decay=0.99):
        self.q_table = {}  # Dictionnaire pour stocker Q-values
        self.alpha = alpha  # Taux d'apprentissage
        self.gamma = gamma  # Facteur de réduction
        self.epsilon = epsilon  # Facteur d'exploration
        self.epsilon_decay = epsilon_decay  # Décroissance de l'exploration
        self.player = player

    def get_q_value(self, state, action):
        # Récupère la Q-value pour une action donnée dans un état donné
        return self.q_table.get((state, action), 0.0)

    
    def choose_action(self, state, available_actions):
        # Choisir une action selon la politique ε-greedy
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(available_actions)  # Exploration
        else:
            # Exploitation: choisir l'action avec la plus grande Q-value
            q_values = [self.get_q_value(state, action) for action in available_actions]
            max_q_value = max(q_values)
            max_q_actions = [action for action in available_actions if self.get_q_value(state, action) == max_q_value]
            return random.choice(max_q_actions)

    def update_q_table(self, state, action, reward, next_state, done):
        # Mise à jour de la Q-value
        max_future_q = max([self.get_q_value(next_state, a) for a in range(9)], default=0)
        current_q = self.get_q_value(state, action)
        if done:
            new_q = reward
        else:
            new_q = current_q + self.alpha * (reward + self.gamma * max_future_q - current_q)
        self.q_table[(state, action)] = new_q

    def decay_epsilon(self):
        self.epsilon *= self.epsilon_decay

# %% [markdown]
# On créer un environnement de jeu qui sera utilisé pendant tout le test

# %%
env = TicTacToeEnv()

# %% [markdown]
# On initialise 2 agents qui vont s'entrainer respectivement a chaque role (1er joueur/ 2eme joueur

# %%
agent_First = QLearningAgent(player=1)
agent_Second = QLearningAgent(player=-1)
agent_MinMaxer_1 = MinimaxAgent(player=1)
agent_MinMaxer_2 = MinimaxAgent(player=-1)

# %%
trainAiVsSmartAgent(agent_First,agent_MinMaxer_2, env, 10000, True)
# Out:
# Épisode 1 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 2 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 3 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 4 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 5 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 6 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 7 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 8 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 9 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 10 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 11 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 12 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 13 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 14 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 15 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 16 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 17 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 18 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 19 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 20 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 21 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 22 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 23 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 24 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 25 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 26 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 27 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 28 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 29 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 30 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 31 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 32 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 33 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 34 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 35 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 36 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 37 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 38 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 39 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 40 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 41 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 42 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 43 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 44 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 45 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 46 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 47 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 48 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 49 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 50 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 51 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 52 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 53 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 54 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 55 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 56 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 57 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 58 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 59 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 60 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 61 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 62 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 63 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 64 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 65 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 66 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 67 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 68 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 69 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 70 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 71 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 72 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 73 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 74 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 75 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 76 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 77 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 78 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 79 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 80 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 81 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 82 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 83 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 84 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 85 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 86 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 87 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 88 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 89 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 90 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 91 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 92 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 93 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 94 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 95 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 96 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 97 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 98 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 99 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 100 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 101 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 102 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 103 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 104 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 105 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 106 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 107 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 108 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 109 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 110 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 111 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 112 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 113 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 114 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 115 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 116 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 117 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 118 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 119 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 120 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 121 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 122 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 123 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 124 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 125 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 126 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 127 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 128 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 129 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 130 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 131 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 132 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 133 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 134 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 135 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 136 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 137 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 138 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 139 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 140 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 141 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 142 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 143 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 144 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 145 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 146 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 147 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 148 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 149 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 150 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 151 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 152 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 153 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 154 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 155 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 156 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 157 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 158 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 159 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 160 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 161 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 162 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 163 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 164 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 165 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 166 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 167 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 168 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 169 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 170 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 171 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 172 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 173 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 174 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 175 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 176 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 177 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 178 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 179 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 180 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 181 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 182 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 183 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 184 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 185 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 186 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 187 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 188 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 189 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 190 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 191 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 192 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 193 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 194 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 195 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 196 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 197 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 198 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 199 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 200 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 201 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 202 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 203 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 204 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 205 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 206 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 207 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 208 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 209 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 210 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 211 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 212 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 213 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 214 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 215 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 216 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 217 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 218 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 219 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 220 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 221 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 222 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 223 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 224 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 225 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 226 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 227 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 228 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 229 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 230 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 231 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 232 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 233 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 234 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 235 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 236 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 237 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 238 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 239 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 240 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 241 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 242 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 243 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 244 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 245 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 246 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 247 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 248 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 249 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 250 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 251 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 252 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 253 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 254 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 255 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 256 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 257 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 258 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 259 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 260 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 261 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 262 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 263 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 264 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 265 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 266 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 267 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 268 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 269 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 270 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 271 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 272 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 273 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 274 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 275 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 276 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 277 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 278 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 279 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 280 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 281 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 282 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 283 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 284 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 285 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 286 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 287 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 288 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 289 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 290 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 291 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 292 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 293 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 294 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 295 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 296 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 297 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 298 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 299 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 300 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 301 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 302 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 303 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 304 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 305 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 306 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 307 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 308 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 309 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 310 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 311 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 312 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 313 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 314 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 315 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 316 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 317 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 318 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 319 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 320 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 321 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 322 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 323 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 324 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 325 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 326 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 327 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 328 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 329 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 330 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 331 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 332 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 333 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 334 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 335 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 336 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 337 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 338 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 339 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 340 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 341 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 342 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 343 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 344 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 345 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 346 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 347 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 348 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 349 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 350 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 351 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 352 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 353 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 354 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 355 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 356 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 357 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 358 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 359 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 360 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 361 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 362 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 363 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 364 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 365 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 366 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 367 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 368 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 369 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 370 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 371 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 372 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 373 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 374 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 375 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 376 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 377 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 378 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 379 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 380 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 381 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 382 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 383 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 384 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 385 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 386 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 387 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 388 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 389 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 390 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 391 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 392 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 393 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 394 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 395 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 396 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 397 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 398 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 399 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 400 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 401 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 402 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 403 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 404 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 405 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 406 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 407 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 408 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 409 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 410 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 411 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 412 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 413 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 414 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 415 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 416 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 417 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 418 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 419 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 420 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 421 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 422 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 423 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 424 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 425 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 426 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 427 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 428 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 429 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 430 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 431 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 432 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 433 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 434 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 435 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 436 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 437 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 438 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 439 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 440 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 441 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 442 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 443 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 444 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 445 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 446 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 447 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 448 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 449 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 450 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 451 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 452 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 453 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 454 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 455 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 456 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 457 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 458 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 459 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 460 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 461 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 462 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 463 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 464 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 465 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 466 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 467 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 468 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 469 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 470 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 471 - Victoires Agent: 0, Victoires Minimax: 0, Égalités: 1
# Épisode 472 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 473 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 474 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 475 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 476 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 477 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 478 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 479 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 480 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 481 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 482 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 483 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 484 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 485 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 486 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 487 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 488 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 489 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 490 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 491 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 492 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 493 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 494 - Victoires Agent: 0, Victoires Minimax: 0, Égalités: 1
# Épisode 495 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 496 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 497 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 498 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 499 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 500 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 501 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 502 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 503 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 504 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 505 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 506 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 507 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 508 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 509 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 510 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 511 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 512 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 513 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 514 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 515 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 516 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 517 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 518 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 519 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 520 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 521 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 522 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 523 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 524 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 525 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 526 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 527 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 528 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 529 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 530 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 531 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 532 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 533 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 534 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 535 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 536 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 537 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 538 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 539 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 540 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 541 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 542 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 543 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 544 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 545 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 546 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 547 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 548 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 549 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 550 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 551 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 552 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 553 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 554 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 555 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 556 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 557 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 558 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 559 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 560 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 561 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 562 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 563 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 564 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 565 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 566 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 567 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 568 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 569 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 570 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 571 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 572 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 573 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 574 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 575 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 576 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 577 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 578 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 579 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 580 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 581 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 582 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 583 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 584 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 585 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 586 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 587 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 588 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 589 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 590 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 591 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 592 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 593 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 594 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 595 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 596 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 597 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 598 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 599 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 600 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 601 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 602 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 603 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 604 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 605 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 606 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 607 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 608 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 609 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 610 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 611 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 612 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 613 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 614 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 615 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 616 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 617 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 618 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 619 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 620 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 621 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 622 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 623 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 624 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 625 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 626 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 627 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 628 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 629 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 630 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 631 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 632 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 633 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 634 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 635 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 636 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 637 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 638 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 639 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 640 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 641 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 642 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 643 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 644 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 645 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 646 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 647 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 648 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 649 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 650 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 651 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 652 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 653 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 654 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 655 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 656 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 657 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 658 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 659 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 660 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 661 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 662 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 663 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 664 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 665 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 666 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 667 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 668 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 669 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 670 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 671 - Victoires Agent: 0, Victoires Minimax: 0, Égalités: 1
# Épisode 672 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 673 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 674 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 675 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 676 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 677 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 678 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 679 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 680 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 681 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 682 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 683 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 684 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 685 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 686 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 687 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 688 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 689 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 690 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 691 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 692 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 693 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 694 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 695 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 696 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 697 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 698 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 699 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 700 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 701 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 702 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 703 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 704 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 705 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 706 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 707 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# ...
# Épisode 1346 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1347 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1348 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1349 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1350 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1351 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1352 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1353 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1354 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1355 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1356 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1357 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1358 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1359 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1360 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1361 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1362 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1363 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1364 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1365 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1366 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1367 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1368 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1369 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1370 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1371 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1372 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1373 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1374 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1375 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1376 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1377 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1378 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1379 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1380 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1381 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1382 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1383 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1384 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1385 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1386 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1387 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1388 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1389 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1390 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1391 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1392 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1393 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1394 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1395 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1396 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1397 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1398 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1399 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1400 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1401 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1402 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1403 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1404 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1405 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1406 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1407 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1408 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1409 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1410 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1411 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1412 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1413 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1414 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1415 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1416 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1417 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1418 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1419 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1420 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1421 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1422 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1423 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1424 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1425 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1426 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1427 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1428 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1429 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1430 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1431 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1432 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1433 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1434 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1435 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1436 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1437 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1438 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1439 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1440 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1441 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1442 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1443 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1444 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1445 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1446 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1447 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1448 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1449 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1450 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1451 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1452 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1453 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1454 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1455 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1456 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1457 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1458 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1459 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1460 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1461 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1462 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1463 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1464 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1465 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1466 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1467 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1468 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1469 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1470 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1471 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1472 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1473 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1474 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1475 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1476 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1477 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1478 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1479 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1480 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1481 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1482 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1483 - Victoires Agent: 0, Victoires Minimax: 0, Égalités: 1
# Épisode 1484 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1485 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1486 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1487 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1488 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1489 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1490 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1491 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1492 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1493 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1494 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1495 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1496 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1497 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1498 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1499 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1500 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1501 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1502 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1503 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1504 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1505 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1506 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1507 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1508 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1509 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1510 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1511 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1512 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1513 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1514 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1515 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1516 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1517 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1518 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1519 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1520 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1521 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1522 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1523 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1524 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1525 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1526 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1527 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1528 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1529 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1530 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1531 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1532 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1533 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1534 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1535 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1536 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1537 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1538 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1539 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1540 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1541 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1542 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1543 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1544 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1545 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1546 - Victoires Agent: 0, Victoires Minimax: 0, Égalités: 1
# Épisode 1547 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1548 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1549 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1550 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1551 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1552 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1553 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1554 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1555 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1556 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1557 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1558 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1559 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1560 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1561 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1562 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1563 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1564 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1565 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1566 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1567 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1568 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1569 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1570 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1571 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1572 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1573 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1574 - Victoires Agent: 0, Victoires Minimax: 1, Égalités: 0
# Épisode 1575 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0
# Épisode 1576 - Victoires Agent: 1, Victoires Minimax: 0, Égalités: 0

# %%
trainAiVsRandom(agent_First, env, 10000, False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 trainAiVsRandom(agent_First, env, 10000, False)
#
# NameError: name 'trainAiVsRandom' is not defined

# %%
trainAiVsRandom(agent_Second, env, 10000, False)
# Out:
# Épisode 1000 - Victoires de l'IA: 519, Défaites de l'IA: 336, Égalités: 145
# Épisode 2000 - Victoires de l'IA: 482, Défaites de l'IA: 363, Égalités: 155
# Épisode 3000 - Victoires de l'IA: 530, Défaites de l'IA: 322, Égalités: 148
# Épisode 4000 - Victoires de l'IA: 516, Défaites de l'IA: 311, Égalités: 173
# Épisode 5000 - Victoires de l'IA: 523, Défaites de l'IA: 331, Égalités: 146
# Épisode 6000 - Victoires de l'IA: 511, Défaites de l'IA: 331, Égalités: 158
# Épisode 7000 - Victoires de l'IA: 524, Défaites de l'IA: 326, Égalités: 150
# Épisode 8000 - Victoires de l'IA: 507, Défaites de l'IA: 333, Égalités: 160
# Épisode 9000 - Victoires de l'IA: 475, Défaites de l'IA: 364, Égalités: 161
# Épisode 10000 - Victoires de l'IA: 530, Défaites de l'IA: 316, Égalités: 154
# Entraînement terminé

# %%
trainAivsAi(agent_First, agent_Second, env)

# Afficher le Q-table
#print(agent_First.q_table)
#print(agent_Second.q_table)
# Out:
# Épisode 1000 - Victoires Agent1: 611, Victoires Agent2: 300, Égalités: 89
# Épisode 2000 - Victoires Agent1: 619, Victoires Agent2: 297, Égalités: 84
# Épisode 3000 - Victoires Agent1: 638, Victoires Agent2: 275, Égalités: 87
# Épisode 4000 - Victoires Agent1: 656, Victoires Agent2: 256, Égalités: 88
# Épisode 5000 - Victoires Agent1: 640, Victoires Agent2: 277, Égalités: 83
# Épisode 6000 - Victoires Agent1: 635, Victoires Agent2: 276, Égalités: 89
# Épisode 7000 - Victoires Agent1: 653, Victoires Agent2: 275, Égalités: 72
# Épisode 8000 - Victoires Agent1: 634, Victoires Agent2: 289, Égalités: 77
# Épisode 9000 - Victoires Agent1: 662, Victoires Agent2: 257, Égalités: 81
# Épisode 10000 - Victoires Agent1: 648, Victoires Agent2: 269, Égalités: 83
# Entraînement terminé

# %%
trainAiVsRandom(agent_First, env, 10000, True)
# Out:
# Épisode 1000 - Victoires de l'IA: 765, Défaites de l'IA: 145, Égalités: 90
# Épisode 2000 - Victoires de l'IA: 785, Défaites de l'IA: 150, Égalités: 65
# Épisode 3000 - Victoires de l'IA: 766, Défaites de l'IA: 155, Égalités: 79
# Épisode 4000 - Victoires de l'IA: 797, Défaites de l'IA: 142, Égalités: 61
# Épisode 5000 - Victoires de l'IA: 791, Défaites de l'IA: 137, Égalités: 72
# Épisode 6000 - Victoires de l'IA: 796, Défaites de l'IA: 136, Égalités: 68
# Épisode 7000 - Victoires de l'IA: 795, Défaites de l'IA: 136, Égalités: 69
# Épisode 8000 - Victoires de l'IA: 783, Défaites de l'IA: 141, Égalités: 76
# Épisode 9000 - Victoires de l'IA: 781, Défaites de l'IA: 139, Égalités: 80
# Épisode 10000 - Victoires de l'IA: 800, Défaites de l'IA: 121, Égalités: 79
# Entraînement terminé

# %%
trainAiVsRandom(agent_Second, env, 10000, False)
# Out:
# Épisode 1000 - Victoires de l'IA: 526, Défaites de l'IA: 296, Égalités: 178
# Épisode 2000 - Victoires de l'IA: 524, Défaites de l'IA: 333, Égalités: 143
# Épisode 3000 - Victoires de l'IA: 498, Défaites de l'IA: 331, Égalités: 171
# Épisode 4000 - Victoires de l'IA: 510, Défaites de l'IA: 319, Égalités: 171
# Épisode 5000 - Victoires de l'IA: 513, Défaites de l'IA: 325, Égalités: 162
# Épisode 6000 - Victoires de l'IA: 499, Défaites de l'IA: 331, Égalités: 170
# Épisode 7000 - Victoires de l'IA: 494, Défaites de l'IA: 336, Égalités: 170
# Épisode 8000 - Victoires de l'IA: 529, Défaites de l'IA: 326, Égalités: 145
# Épisode 9000 - Victoires de l'IA: 513, Défaites de l'IA: 334, Égalités: 153
# Épisode 10000 - Victoires de l'IA: 504, Défaites de l'IA: 325, Égalités: 171
# Entraînement terminé
